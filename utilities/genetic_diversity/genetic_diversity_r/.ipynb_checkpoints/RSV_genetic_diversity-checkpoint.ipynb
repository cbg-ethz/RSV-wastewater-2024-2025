# %%
library(lme4)
library(ggplot2)
library(dplyr)
library(robustbase)
library(stringr)
library(tidyr)
library(ggpubr)
library(dplyr)
library(rstatix)
library(brms)
library(slider)
library(lubridate)
library(patchwork)
library(purrr)
library(nlme)
library(writexl)

library(tidyverse)
library(emmeans)
library(performance)
library(DHARMa)
library(splines)
library(glmmTMB)

# %% [markdown]
# # Genetic diversity analysis

# %%
# load the data with genetic diversity estimates per sample
rsva_diversity_matrix <- read.csv("../../../RSV_results/data_analysis/results/RSVA_2024_2025/genetic_diversity/Switzerland-RSV-A-2024-2025_genetic_diversity.csv",
                                 colClasses = c(location = "character"))

rsvb_diversity_matrix <- read.csv("../../../RSV_results/data_analysis/results/RSVB_2024_2025/genetic_diversity/Switzerland-RSV-B-2024-2025_genetic_diversity.csv",
                                 colClasses = c(location = "character"))


# merge genetic diversity dataframes
rsv_div_matrix <- rbind(rsva_diversity_matrix, rsvb_diversity_matrix)
# center the date
rsv_div_matrix <- rsv_div_matrix %>%
  mutate(location = factor(location)) %>%
  mutate(genome_region = factor(genome_region)) %>%
rename(ID = sample_id) %>%
select(-c(1)) %>%
mutate(date = as.Date(date, format = "%Y_%m_%d"))


# Filter out the samples that are covered less than 50% of the genome (or particular gene)
rsv_div_matrix <- rsv_div_matrix %>% filter(
  (covered_part >= 0.5)
)
rsv_div_matrix$location <- gsub("10", "Zurich", rsv_div_matrix$location)
rsv_div_matrix$location <- gsub("16", "Geneva", rsv_div_matrix$location)
rsv_div_matrix$location <- gsub("15", "Basel", rsv_div_matrix$location)
rsv_div_matrix$location <- gsub("05", "Lugano", rsv_div_matrix$location)
rsv_div_matrix$location <- gsub("25", "Laupen", rsv_div_matrix$location)
rsv_div_matrix$location <- gsub("17", "Chur", rsv_div_matrix$location)

rsv_div_matrix$subtype <- gsub("-", "_", rsv_div_matrix$subtype)

#rsv_div_matrix <- rsv_div_matrix %>%
  #group_by(genome_region)

# %%
head(rsv_div_matrix)
# Out:
#   ID               date       location subtype genome_region entropy
# 1 F1_10_2024_11_09 2024-11-09 Zurich   RSV_A   G             0.0005695969
# 2 E1_10_2024_11_16 2024-11-16 Zurich   RSV_A   G             0.0023957615
# 3 A2_17_2024_11_24 2024-11-24 Chur     RSV_A   G             0.0019805914
# 4 A2_17_2024_11_24 2024-11-24 Chur     RSV_A   F             0.0028228623
# 5 A2_17_2024_11_24 2024-11-24 Chur     RSV_A   genome        0.0018235380
# 6 D1_10_2024_11_25 2024-11-25 Zurich   RSV_A   G             0.0029851261
#   nuc_diversity covered_part mean_pos_coverage richness low_freq_polymorphisms
# 1 0.0001973822  0.6946170    2021.683          25.33532 0.0000000
# 2 0.0013614424  0.5434783    3713.734          45.71429 0.0000000
# 3 0.0011097650  0.9648033    8454.416          25.75107 0.0000000
# 4 0.0019600457  0.6475362    3465.988          11.63832 0.8952551
# 5 0.0011297796  0.6011823    2667.041          16.16956 0.9832842
# 6 0.0018295970  0.6480331    4740.844          38.33866 1.5974441

# %% [markdown]
# #  Compare diversity between RSV-A and RSV-B subtypes for each genome region

# %%
rsv_div_matrix %>%
  group_by(genome_region, subtype) %>%
summarize(counts = n())
# Out:
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by genome_region and subtype.
# ℹ Output is grouped by genome_region.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(genome_region, subtype))` for per-operation grouping
#   (`?dplyr::dplyr_by`) instead.
#   genome_region subtype counts
# 1 F             RSV_A   51
# 2 F             RSV_B   69
# 3 G             RSV_A   76
# 4 G             RSV_B   73
# 5 genome        RSV_A   59
# 6 genome        RSV_B   45

# %% [markdown]
# # Diversity metrics

# %%
rsv_div_matrix_genes <- rsv_div_matrix[rsv_div_matrix$genome_region %in% c("F", "G"), ]
head(rsv_div_matrix_genes)
# Out:
#   ID               date       location subtype genome_region entropy
# 1 F1_10_2024_11_09 2024-11-09 Zurich   RSV_A   G             0.0005695969
# 2 E1_10_2024_11_16 2024-11-16 Zurich   RSV_A   G             0.0023957615
# 3 A2_17_2024_11_24 2024-11-24 Chur     RSV_A   G             0.0019805914
# 4 A2_17_2024_11_24 2024-11-24 Chur     RSV_A   F             0.0028228623
# 6 D1_10_2024_11_25 2024-11-25 Zurich   RSV_A   G             0.0029851261
# 7 D1_10_2024_11_25 2024-11-25 Zurich   RSV_A   F             0.0004864825
#   nuc_diversity covered_part mean_pos_coverage richness low_freq_polymorphisms
# 1 0.0001973822  0.6946170    2021.683          25.33532 0.0000000
# 2 0.0013614424  0.5434783    3713.734          45.71429 0.0000000
# 3 0.0011097650  0.9648033    8454.416          25.75107 0.0000000
# 4 0.0019600457  0.6475362    3465.988          11.63832 0.8952551
# 6 0.0018295970  0.6480331    4740.844          38.33866 1.5974441
# 7 0.0002039714  0.8655072    2642.370          11.38647 2.0093771

# %%
genes <- c("F", "G")
metrics <- c("entropy", "nuc_diversity")

# Per-gene models: compare subtypes within gene
for(g in genes){
  for(m in metrics){
    formula <- as.formula(paste(m, "~ subtype + (1|location) + log(mean_pos_coverage)"))
    assign(paste0(m, "_", g),
           glmmTMB(formula,
                   family = Gamma(link = "log"),
                   data = rsv_div_matrix[
                     rsv_div_matrix$genome_region == g, ]))
  }
}



metrics <- c("entropy", "nuc_diversity", "richness")

# RSV-A only: compare F vs G
for(m in metrics){
  formula <- as.formula(paste(m, "~ genome_region + (1|location) + log(mean_pos_coverage)"))
  assign(paste0(m, "_RSV_A"),
         glmmTMB(formula,
                 family = Gamma(link = "log"),
                 data = rsv_div_matrix_genes[
                   rsv_div_matrix_genes$subtype == "RSV_A", ]))
}

# RSV-B only: compare F vs G
for(m in metrics){
  formula <- as.formula(paste(m, "~ genome_region + (1|location) + log(mean_pos_coverage)"))
  assign(paste0(m, "_RSV_B"),
         glmmTMB(formula,
                 family = Gamma(link = "log"),
                 data = rsv_div_matrix_genes[
                   rsv_div_matrix_genes$subtype == "RSV_B", ]))
}

# %% [raw]
# genes <- c("F", "G")
# metrics <- c("low_freq_polymorphisms")
#
# # Per-gene models
# for(g in genes){
#   for(m in metrics){
#     formula <- as.formula(paste(m, "~ subtype + (1|location) + log(mean_pos_coverage)"))
#     assign(paste0(m, "_", g),
#            glmmTMB(formula,
#                    family = tweedie(link = "log"),
#                    data = rsv_div_matrix[
#                      rsv_div_matrix$genome_region == g, ]))
#   }
# }
#
#
# # per-subtype models: compare genes within subtype
#
# # RSV-A only: compare F vs G
# for(m in metrics){
#   formula <- as.formula(paste(m, "~ genome_region + (1|location) + log(mean_pos_coverage)"))
#   assign(paste0(m, "_RSV_A"),
#          glmmTMB(formula,
#                  family = tweedie(link = "log"),
#                  data = rsv_div_matrix_genes[
#                    rsv_div_matrix_genes$subtype == "RSV_A", ]))
# }
#
# # RSV-B only: compare F vs G
# for(m in metrics){
#   formula <- as.formula(paste(m, "~ genome_region + (1|location) + log(mean_pos_coverage)"))
#   assign(paste0(m, "_RSV_B"),
#          glmmTMB(formula,
#                  family = tweedie(link = "log"),
#                  data = rsv_div_matrix_genes[
#                    rsv_div_matrix_genes$subtype == "RSV_B", ]))
# }

# %%
metrics <- c("entropy", "nuc_diversity")

for(m in metrics){
  formula <- as.formula(paste(m, "~ subtype + (1|location) + log(mean_pos_coverage)"))
  assign(paste0(m, "_full_genome"),
         glmmTMB(formula,
                 family = Gamma(link = "log"),
                 data = rsv_div_matrix[
                     rsv_div_matrix$genome_region == "genome", ]))
}

# %% [raw]
# metrics <- c("low_freq_polymorphisms")
#
# for(m in metrics){
#   formula <- as.formula(paste(m, "~ subtype + (1|location) + log(mean_pos_coverage)"))
#   assign(paste0(m, "_full_genome"),
#          glmmTMB(formula,
#                  family = tweedie(link = "log"),
#                  data = rsv_div_matrix[
#                      rsv_div_matrix$genome_region == "genome", ]))
# }

# %%
library(emmeans)
# Goals - subtype constrast within full-genome
genome_models <- list(
    entropy_full_genome = entropy_full_genome,
    nuc_diversity_full_genome = nuc_diversity_full_genome,
    richness_full_genome = richness_full_genome
)

# Goals - subtype contrast within each gene
gene_models <- list(
  entropy_F       = entropy_F,
  entropy_G       = entropy_G,
  nuc_diversity_F = nuc_diversity_F,
  nuc_diversity_G = nuc_diversity_G,
  richness_F      = richness_F,
  richness_G      = richness_G
)

# Goals - gene contrast within each subtype
subtype_models <- list(
  entropy_RSV_A       = entropy_RSV_A,
  entropy_RSV_B       = entropy_RSV_B,
  nuc_diversity_RSV_A = nuc_diversity_RSV_A,
  nuc_diversity_RSV_B = nuc_diversity_RSV_B,
  richness_RSV_A      = richness_RSV_A,
  richness_RSV_B      = richness_RSV_B
)

# extraction function 
extract_emmeans <- function(model, model_name, predictor) {
  emm  <- emmeans(model, as.formula(paste("~", predictor)), 
                  type = "response")
  cont <- pairs(emm, type = "response")
  
  list(
    means     = as.data.frame(emm)  %>% mutate(model = model_name),
    contrasts = as.data.frame(cont) %>% mutate(model = model_name)
  )
}

# Apply — note predictor differs between the two sets
results_genomes    <- lapply(names(genome_models), function(n)
  extract_emmeans(genome_models[[n]],    n, "subtype"))

results_genes    <- lapply(names(gene_models), function(n)
  extract_emmeans(gene_models[[n]],    n, "subtype"))

results_subtypes <- lapply(names(subtype_models), function(n)
  extract_emmeans(subtype_models[[n]], n, "genome_region"))

# Combine contrasts
contrasts_genomes    <- bind_rows(lapply(results_genomes,    `[[`, "contrasts"))
contrasts_genes    <- bind_rows(lapply(results_genes,    `[[`, "contrasts"))
contrasts_subtypes <- bind_rows(lapply(results_subtypes, `[[`, "contrasts"))

# Correct for multiple testing separately within each comparison type
contrasts_genomes <- contrasts_genomes %>%
  mutate(p.adjusted = p.adjust(p.value, method = "BH"))

contrasts_genes <- contrasts_genes %>%
  mutate(p.adjusted = p.adjust(p.value, method = "BH"))

contrasts_subtypes <- contrasts_subtypes %>%
  mutate(p.adjusted = p.adjust(p.value, method = "BH"))

# %%
descriptives_formatted <- rsv_div_matrix %>%
  filter(genome_region %in% c("genome", "F", "G")) %>%
  group_by(subtype, genome_region) %>%
  summarise(
    n = n(),
    across(
      c(entropy, nuc_diversity, richness),
      list(
        median = ~ round(median(.), 4),
        Q1     = ~ round(quantile(., 0.25), 4),
        Q3     = ~ round(quantile(., 0.75), 4)
      )
    ),
    .groups = "drop"
  ) %>%
  mutate(
    Shannon_entropy        = paste0(entropy_median,
                               " (", entropy_Q1, "–", entropy_Q3, ")"),
    Nucleotide_diversity   = paste0(nuc_diversity_median,
                               " (", nuc_diversity_Q1, "–", nuc_diversity_Q3, ")"),
    Richness               = paste0(richness_median,
                               " (", richness_Q1, "–", richness_Q3, ")")
  ) %>%
  select(genome_region, subtype, n,
         Shannon_entropy, Nucleotide_diversity,
         Richness) %>%
  mutate(
    genome_region = case_when(
      genome_region == "genome" ~ "Whole genome",
      genome_region == "F"      ~ "F gene",
      genome_region == "G"      ~ "G gene"
    ),
    subtype = case_when(
      subtype == "RSV_A" ~ "RSV-A",
      subtype == "RSV_B" ~ "RSV-B"
    )
  ) %>%
  arrange(genome_region, subtype)
write_xlsx(
    descriptives_formatted, 
    path = "descriptives_formatted.xlsx"
)

# %%
descriptives_formatted
# Out:
#   genome_region subtype n  Shannon_entropy        Nucleotide_diversity
# 1 F gene        RSV-A   51 0.0024 (0.0012–0.0046) 0.0015 (7e-04–0.003)
# 2 F gene        RSV-B   69 8e-04 (4e-04–0.0013)   4e-04 (2e-04–8e-04)
# 3 G gene        RSV-A   76 0.0056 (0.0023–0.0114) 0.0035 (0.0013–0.0076)
# 4 G gene        RSV-B   73 0.0045 (0.0016–0.0096) 0.0029 (7e-04–0.0061)
# 5 Whole genome  RSV-A   59 0.0057 (0.0039–0.0067) 0.0038 (0.0025–0.0045)
# 6 Whole genome  RSV-B   45 0.0027 (0.0017–0.0037) 0.0018 (0.0011–0.0024)
#   Richness
# 1 13.624 (11.1802–16.5856)
# 2 11.2782 (9.8551–13.3753)
# 3 37.0551 (31.041–45.0715)
# 4 31.1355 (25.641–35.7143)
# 5 20.3541 (18.4329–22.4529)
# 6 14.1156 (11.9168–15.1457)

# %%
library(dplyr)

# Add comparison type and parse model name
contrasts_all <- bind_rows(
  contrasts_genomes  %>% mutate(comparison_type = "Subtype, whole genome"),
  contrasts_genes    %>% mutate(comparison_type = "Subtype, gene level"),
  contrasts_subtypes %>% mutate(comparison_type = "Gene, within subtype")
) %>%
  # Parse metric and gene/subtype from model name
  mutate(
    metric = case_when(
      grepl("^entropy",       model) ~ "Shannon entropy",
      grepl("^nuc_diversity", model) ~ "Nucleotide diversity",
      grepl("^richness",      model) ~ "Richness"
    ),
    group = case_when(
      grepl("_F$",     model) ~ "F gene",
      grepl("_G$",     model) ~ "G gene",
      grepl("RSV_A$",  model) ~ "RSV-A",
      grepl("RSV_B$",  model) ~ "RSV-B",
      grepl("genome",  model) ~ "Whole genome"
    )
  )

# %%
results_table <- contrasts_all %>%
  select(comparison_type, group, contrast, metric, 
         ratio, SE, z.ratio, p.value, p.adjusted) %>%
  mutate(
    ratio      = round(ratio,      3),
    SE         = round(SE,         3),
    z.ratio    = round(z.ratio,    3),
    p.value    = p.value,
    p.adjusted = p.adjusted,
    significant = ifelse(p.adjusted < 0.05, "*", "")
  ) %>%
  arrange(comparison_type, group, contrast, metric)

print(results_table)
# Out:
#          comparison_type        group      contrast               metric ratio
# 1   Gene, within subtype        RSV-A         F / G Nucleotide diversity 0.555
# 2   Gene, within subtype        RSV-A         F / G             Richness 0.391
# 3   Gene, within subtype        RSV-A         F / G      Shannon entropy 0.524
# 4   Gene, within subtype        RSV-B         F / G Nucleotide diversity 0.171
# 5   Gene, within subtype        RSV-B         F / G             Richness 0.371
# 6   Gene, within subtype        RSV-B         F / G      Shannon entropy 0.186
# 7    Subtype, gene level       F gene RSV_A / RSV_B Nucleotide diversity 3.077
# 8    Subtype, gene level       F gene RSV_A / RSV_B             Richness 1.240
# 9    Subtype, gene level       F gene RSV_A / RSV_B      Shannon entropy 2.800
# 10   Subtype, gene level       G gene RSV_A / RSV_B Nucleotide diversity 1.007
# 11   Subtype, gene level       G gene RSV_A / RSV_B             Richness 1.178
# 12   Subtype, gene level       G gene RSV_A / RSV_B      Shannon entropy 1.046
# 13 Subtype, whole genome Whole genome RSV_A / RSV_B Nucleotide diversity 2.048
# 14 Subtype, whole genome Whole genome RSV_A / RSV_B             Richness 1.515
# 15 Subtype, whole genome Whole genome RSV_A / RSV_B      Shannon entropy 2.030
#       SE z.ratio      p.value   p.adjusted significant
# 1  0.105  -3.106 1.894120e-03 1.894120e-03           *
# 2  0.018 -20.223 6.142082e-91 1.842624e-90           *
# 3  0.088  -3.852 1.171051e-04 1.405261e-04           *
# 4  0.032  -9.585 9.220293e-22 1.383044e-21           *
# 5  0.018 -20.852 1.464088e-96 8.784529e-96           *
# 6  0.030 -10.507 7.995631e-26 1.599126e-25           *
# 7  0.684   5.058 4.246575e-07 1.273972e-06           *
# 8  0.063   4.223 2.407063e-05 4.814125e-05           *
# 9  0.538   5.363 8.180940e-08 4.908564e-07           *
# 10 0.175   0.042 9.668736e-01 9.668736e-01
# 11 0.053   3.631 2.825380e-04 4.238070e-04           *
# 12 0.160   0.295 7.680336e-01 9.216404e-01
# 13 0.209   7.034 2.004194e-12 2.004194e-12           *
# 14 0.047  13.477 2.144330e-41 6.432991e-41           *
# 15 0.194   7.418 1.185304e-13 1.777955e-13           *

# %%
means_all <- bind_rows(
  bind_rows(lapply(results_genomes,  `[[`, "means")) %>% 
    mutate(comparison_type = "Subtype, whole genome"),
  bind_rows(lapply(results_genes,    `[[`, "means")) %>% 
    mutate(comparison_type = "Subtype, gene level"),
  bind_rows(lapply(results_subtypes, `[[`, "means")) %>% 
    mutate(comparison_type = "Gene, within subtype")
) %>%
  mutate(
    metric = case_when(
      grepl("^entropy",       model) ~ "Shannon entropy",
      grepl("^nuc_diversity", model) ~ "Nucleotide diversity",
      grepl("^richness",      model) ~ "Richness"
    ),
    group = case_when(
      grepl("_F$",    model) ~ "F gene",
      grepl("_G$",    model) ~ "G gene",
      grepl("RSV_A$", model) ~ "RSV-A",
      grepl("RSV_B$", model) ~ "RSV-B",
      grepl("genome", model) ~ "Whole genome"
    )
  ) %>%
  mutate(
    across(c(response, asymp.LCL, asymp.UCL), ~ round(., 5))
  )

# %%
contrasts_all_clean <- contrasts_all %>%
  mutate(
    # Who was compared with whom — parsed from emmeans contrast column
    compared      = contrast,  # already contains "RSV_A / RSV_B" or "F / G"

    # Where — the data context
    genomic_level = case_when(
      comparison_type == "Subtype, whole genome" ~ "Whole genome",
      comparison_type == "Subtype, gene level"   ~ group,  # F gene or G gene
      comparison_type == "Gene, within subtype"  ~ group   # RSV-A or RSV-B
    ),

    # What is being tested
    fixed_effect = case_when(
      comparison_type %in% c("Subtype, whole genome",
                              "Subtype, gene level") ~ "Subtype",
      comparison_type == "Gene, within subtype"      ~ "Gene"
    )
  ) %>%
mutate(
    significant = ifelse(p.adjusted < 0.05, "*", "")
  ) %>%
  select(fixed_effect, genomic_level, metric,
         compared, ratio, SE, z.ratio, p.value, p.adjusted, significant)
contrasts_all_clean
# Out:
#    fixed_effect genomic_level metric               compared      ratio
# 1  Subtype      Whole genome  Shannon entropy      RSV_A / RSV_B 2.0302841
# 2  Subtype      Whole genome  Nucleotide diversity RSV_A / RSV_B 2.0477408
# 3  Subtype      Whole genome  Richness             RSV_A / RSV_B 1.5152434
# 4  Subtype      F gene        Shannon entropy      RSV_A / RSV_B 2.8003670
# 5  Subtype      G gene        Shannon entropy      RSV_A / RSV_B 1.0461832
# 6  Subtype      F gene        Nucleotide diversity RSV_A / RSV_B 3.0772693
# 7  Subtype      G gene        Nucleotide diversity RSV_A / RSV_B 1.0072482
# 8  Subtype      F gene        Richness             RSV_A / RSV_B 1.2402513
# 9  Subtype      G gene        Richness             RSV_A / RSV_B 1.1781653
# 10 Gene         RSV-A         Shannon entropy      F / G         0.5244053
# 11 Gene         RSV-B         Shannon entropy      F / G         0.1862572
# 12 Gene         RSV-A         Nucleotide diversity F / G         0.5554877
# 13 Gene         RSV-B         Nucleotide diversity F / G         0.1712835
# 14 Gene         RSV-A         Richness             F / G         0.3908682
# 15 Gene         RSV-B         Richness             F / G         0.3705943
#    SE         z.ratio      p.value      p.adjusted   significant
# 1  0.19381472   7.41841484 1.185304e-13 1.777955e-13 *
# 2  0.20865111   7.03419170 2.004194e-12 2.004194e-12 *
# 3  0.04672495  13.47671876 2.144330e-41 6.432991e-41 *
# 4  0.53768969   5.36309180 8.180940e-08 4.908564e-07 *
# 5  0.16014231   0.29494794 7.680336e-01 9.216404e-01
# 6  0.68392321   5.05755881 4.246575e-07 1.273972e-06 *
# 7  0.17516030   0.04152978 9.668736e-01 9.668736e-01
# 8  0.06323037   4.22334187 2.407063e-05 4.814125e-05 *
# 9  0.05320311   3.63080556 2.825380e-04 4.238070e-04 *
# 10 0.08787359  -3.85210853 1.171051e-04 1.405261e-04 *
# 11 0.02979158 -10.50729224 7.995631e-26 1.599126e-25 *
# 12 0.10513177  -3.10635052 1.894120e-03 1.894120e-03 *
# 13 0.03152944  -9.58528477 9.220293e-22 1.383044e-21 *
# 14 0.01815633 -20.22300853 6.142082e-91 1.842624e-90 *
# 15 0.01764199 -20.85192614 1.464088e-96 8.784529e-96 *

# %%
write_xlsx(
  list(
    marginal_means = means_all %>%
      select(comparison_type, subtype, genome_region, group, metric, 
             response, asymp.LCL, asymp.UCL),
    contrasts      = contrasts_all_clean
  ),
  path = "RSV_diversity_results.xlsx"
)

# %%
plot_subtypes
# Out:
#   contrast      ratio    SE         df  null z.ratio     p.value
# 1 RSV_A / RSV_B 2.030284 0.19381472 Inf 1     7.41841484 1.185304e-13
# 2 RSV_A / RSV_B 2.047741 0.20865111 Inf 1     7.03419170 2.004194e-12
# 3 RSV_A / RSV_B 1.515243 0.04672495 Inf 1    13.47671876 2.144330e-41
# 4 RSV_A / RSV_B 2.800367 0.53768969 Inf 1     5.36309180 8.180940e-08
# 5 RSV_A / RSV_B 1.046183 0.16014231 Inf 1     0.29494794 7.680336e-01
# 6 RSV_A / RSV_B 3.077269 0.68392321 Inf 1     5.05755881 4.246575e-07
# 7 RSV_A / RSV_B 1.007248 0.17516030 Inf 1     0.04152978 9.668736e-01
# 8 RSV_A / RSV_B 1.240251 0.06323037 Inf 1     4.22334187 2.407063e-05
# 9 RSV_A / RSV_B 1.178165 0.05320311 Inf 1     3.63080556 2.825380e-04
#   model                     p.adjusted   level        metric
# 1 entropy_full_genome       1.777955e-13 Whole genome Shannon entropy
# 2 nuc_diversity_full_genome 2.004194e-12 Whole genome Nucleotide diversity
# 3 richness_full_genome      6.432991e-41 Whole genome Richness
# 4 entropy_F                 4.908564e-07 F gene       Shannon entropy
# 5 entropy_G                 9.216404e-01 G gene       Shannon entropy
# 6 nuc_diversity_F           1.273972e-06 F gene       Nucleotide diversity
# 7 nuc_diversity_G           9.668736e-01 G gene       Nucleotide diversity
# 8 richness_F                4.814125e-05 F gene       Richness
# 9 richness_G                4.238070e-04 G gene       Richness
#   lower     upper     significant
# 1 1.3886040  2.968488  TRUE
# 2 1.3604030  3.082353  TRUE
# 3 1.3826407  1.660563  TRUE
# 4 0.9761673  8.033516  TRUE
# 5 0.7643493  1.431936 FALSE
# 6 0.8053753 11.757979  TRUE
# 7 0.7145572  1.419829 FALSE
# 8 1.0956880  1.403888  TRUE
# 9 1.0614972  1.307656  TRUE

# %%
options(repr.plot.width = 7, repr.plot.height = 12)


# Prepare data
plot_subtypes <- bind_rows(
  contrasts_genomes %>% mutate(level = "Genome"),
  contrasts_genes   %>% mutate(level = case_when(
    grepl("_F$", model) ~ "F gene",
    grepl("_G$", model) ~ "G gene"
  ))
) %>%
  mutate(
    metric = case_when(
      grepl("^entropy",       model) ~ "Shannon entropy",
      grepl("^nuc_diversity", model) ~ "Nucleotide diversity",
      grepl("^richness",      model) ~ "Richness"
    ),
    level = factor(level, levels = c("Genome", "G gene", "F gene")),
    # confidence interval from SE on log scale
    lower = exp(log(ratio) - 1.96 * SE),
    upper = exp(log(ratio) + 1.96 * SE),
    significant = p.adjusted < 0.05
  )

ggplot(plot_subtypes, 
       aes(x = ratio, y = level, 
           xmin = lower, xmax = upper,
           colour = significant,
           shape  = significant)) +
  geom_pointrange(size = 1.2, linewidth = 1) +
  geom_vline(xintercept = 1, linetype = "dashed", colour = "grey60", linewidth = 1.5) +
  facet_wrap(~ metric, ncol = 1, scales = "free_x") +
  scale_colour_manual(
    values = c("TRUE" = "black", "FALSE" = "#888780"),
    labels = c("TRUE" = "Significant (BH)", "FALSE" = "Non-significant")
  ) +
  scale_shape_manual(
    values = c("TRUE" = 16, "FALSE" = 1),
    labels = c("TRUE" = "Significant (BH)", "FALSE" = "Non-significant")
  ) +
  labs(
    x      = "Ratio RSV-A / RSV-B (95% CI)",
    y      = NULL,
    colour = NULL,
    shape  = NULL,
    title  = "RSV subtype differences in diversity"
  ) +
  theme_bw(base_size = 20) +
theme_bw() +
  theme(
    text         = element_text(size = 20),      # all text base size
    axis.title   = element_text(size = 20),      # axis labels
    axis.text.x    = element_text(size = 20),      # axis tick labels
    axis.text.y    = element_text(size = 23),      # axis tick labels

    legend.text  = element_text(size = 20),      # legend items
    legend.title = element_text(size = 20),      # legend title
    plot.title   = element_text(size = 23,       # plot title
                                face = "bold"),
    strip.text   = element_text(size = 23),      # facet labels if any

    legend.position = "bottom",
    strip.background = element_rect(fill = "grey95"),
    panel.grid.minor = element_blank()
  )
# Out:
# plot without title

# %%
options(repr.plot.width = 7, repr.plot.height = 12)

plot_genes <- contrasts_subtypes %>%
  mutate(
    metric = case_when(
      grepl("^entropy",       model) ~ "Shannon entropy",
      grepl("^nuc_diversity", model) ~ "Nucleotide diversity",
      grepl("^richness",      model) ~ "Richness"
    ),
    subtype = case_when(
      grepl("RSV_A$", model) ~ "RSV-A",
      grepl("RSV_B$", model) ~ "RSV-B"
    ),
    lower = exp(log(ratio) - 1.96 * SE),
    upper = exp(log(ratio) + 1.96 * SE),
    significant = p.adjusted < 0.05
  )

ggplot(plot_genes,
       aes(x = ratio, y = subtype,
           xmin = lower, xmax = upper,
           colour = significant,
           shape  = significant)) +
  geom_pointrange(size = 1.2, linewidth = 1) +
  geom_vline(xintercept = 1, linetype = "dashed", colour = "grey60", linewidth = 1.5) +
  facet_wrap(~ metric, ncol = 1, scales = "free_x") +
  scale_colour_manual(
    values = c("TRUE" = "black", "FALSE" = "#888780"),
    labels = c("TRUE" = "Significant (BH)", "FALSE" = "Non-significant")
  ) +
  scale_shape_manual(
    values = c("TRUE" = 16, "FALSE" = 1),
    labels = c("TRUE" = "Significant (BH)", "FALSE" = "Non-significant")
  ) +
  labs(
    x      = "Ratio F / G (95% CI)",
    y      = NULL,
    colour = NULL,
    shape  = NULL,
    title  = "Gene differences in diversity \n within each subtype"
  ) +
  theme_bw(base_size = 20) +
theme_bw() +
theme(
    text         = element_text(size = 20),      # all text base size
    axis.title   = element_text(size = 20),      # axis labels
    axis.text    = element_text(size = 20),      # axis tick labels
    legend.text  = element_text(size = 20),      # legend items
    legend.title = element_text(size = 20),      # legend title
    plot.title   = element_text(size = 23,       # plot title
                                face = "bold"),
    strip.text   = element_text(size = 23),      # facet labels if any

    legend.position = "bottom",
    strip.background = element_rect(fill = "grey95"),
    panel.grid.minor = element_blank()
  )
# Out:
# plot without title

# %% [raw]
# options(repr.plot.width = 15, repr.plot.height = 5)
#
# # Reshape to long format for plotting
# library(tidyr)
#
# rsv_long <- rsv_div_matrix %>%
#   filter(genome_region %in% c("genome", "F", "G")) %>%
#   pivot_longer(
#     cols = c(entropy, nuc_diversity, richness, low_freq_polymorphisms),
#     names_to  = "metric",
#     values_to = "value"
#   ) %>%
#   mutate(
#     metric = case_when(
#       metric == "entropy"                ~ "Shannon entropy",
#       metric == "nuc_diversity"          ~ "Nucleotide diversity",
#       metric == "richness"               ~ "Richness",
#       metric == "low_freq_polymorphisms" ~ "Low-freq. polymorphisms"
#     ),
#     genome_region = factor(genome_region,
#                            levels = c("genome", "F", "G"),
#                            labels = c("Whole genome", "F gene", "G gene"))
#   )
#
# ggplot(rsv_long,
#        aes(x = subtype, y = value, fill = subtype)) +
#   geom_boxplot(alpha = 0.6, outlier.shape = NA) +
#   geom_jitter(width = 0.15, alpha = 0.4, size = 1.2) +
#   facet_grid(metric ~ genome_region, scales = "free_y") +
#   scale_fill_manual(values = c("RSV_A" = "#378ADD",
#                                 "RSV_B" = "#D85A30")) +
#   labs(
#     x     = NULL,
#     y     = "Diversity value",
#     fill  = "Subtype",
#     title = "Distribution of diversity metrics by subtype and genome region"
#   ) +
#   theme_bw(base_size = 13) +
#   theme(
#     legend.position  = "bottom",
#     strip.background = element_rect(fill = "grey95"),
#     panel.grid.minor = element_blank(),
#     axis.text.x      = element_text(angle = 45, hjust = 1)
#   )

# %%
library(writexl)

# Export all results to Excel with separate sheets
write_xlsx(
  list(
    contrasts_genomes = contrasts_genomes,
    contrasts_genes     = contrasts_genes,
    contrasts_subtypes        = contrasts_subtypes
  ),
  path = "model_results.xlsx"
)

# %% [raw]
# options(repr.plot.width = 14, repr.plot.height = 5)
#
# contrasts_table %>%
#   mutate(
#     metric = gsub("_F$|_G$", "", model),
#     gene   = case_when(
#       grepl("_F$", model) ~ "F",
#       grepl("_G$", model) ~ "G",
#       TRUE ~ "Whole genome"
#     )
#   ) %>%
#   ggplot(aes(x = metric, y = ratio,
#              ymin = ratio - SE, ymax = ratio + SE,
#              colour = gene)) +
#   geom_pointrange(position = position_dodge(0.4)) +
#   geom_hline(yintercept = 1, linetype = "dashed") +
#   labs(y = "Ratio RSV-A / RSV-B",
#        x = "Diversity metric",
#        title = "Subtype differences across metrics and genome regions") +
# theme_bw() +
#   theme(
#     text         = element_text(size = 16),      # all text base size
#     axis.title   = element_text(size = 18),      # axis labels
#     axis.text    = element_text(size = 18),      # axis tick labels
#     legend.text  = element_text(size = 14),      # legend items
#     legend.title = element_text(size = 16),      # legend title
#     plot.title   = element_text(size = 20,       # plot title
#                                 face = "bold"),
#     strip.text   = element_text(size = 14)       # facet labels if any
#   )

# %% [raw]
# For all models residual diagnostics indicated approximate uniformity of scaled residuals, no evidence of overdispersion, and no significant quantile deviations or heteroscedasticity across predicted values.

# %%
library(DHARMa)

# Run diagnostics for all models at once
run_diagnostics <- function(model, model_name) {
  
  cat("\n==============================\n")
  cat("Model:", model_name, "\n")
  cat("==============================\n")
  
  sim_res <- simulateResiduals(model, n = 1000)
  
  # Main plot — uniformity + dispersion + outliers
  plot(sim_res, main = model_name)
  
  # Individual tests
  tests <- list(
    uniformity  = testUniformity(sim_res,  plot = FALSE),
    dispersion  = testDispersion(sim_res,  plot = FALSE),
    outliers    = testOutliers(sim_res,    plot = FALSE),
    zero_infl   = testZeroInflation(sim_res, plot = FALSE)
  )
  
  # Summarise as data frame
  data.frame(
    model       = model_name,
    test        = names(tests),
    statistic   = sapply(tests, function(t) round(t$statistic, 4)),
    p_value     = sapply(tests, function(t) round(t$p.value, 4)),
    problem     = sapply(tests, function(t) t$p.value < 0.05)
  )
}

# Apply to all models
all_models <- c(genome_models, gene_models)

diag_results <- bind_rows(
  lapply(names(all_models), function(n) {
    run_diagnostics(all_models[[n]], n)
  })
)

print(diag_results)

# %%
test_autocorrelation <- function(model, data, model_name) {
  
  sim_res <- simulateResiduals(model, n = 1000)
  
  # Test autocorrelation — requires time variable
  ac_test <- testTemporalAutocorrelation(
    sim_res,
    time = data$time,   # replace with your actual time variable name
    plot = TRUE)
  
  data.frame(
    model     = model_name,
    statistic = round(ac_test$statistic, 4),
    p_value   = round(ac_test$p.value, 4),
    problem   = ac_test$p.value < 0.05
  )
}

# For genome models
ac_genome <- bind_rows(
  lapply(names(genome_models), function(n) {
    test_autocorrelation(genome_models[[n]], 
                         rsv_div_matrix_full_genome, n)
  })
)

# For gene models
ac_genes <- bind_rows(
  lapply(names(gene_models), function(n) {
    g <- ifelse(grepl("_F$", n), "F", "G")
    test_autocorrelation(
      gene_models[[n]],
      rsv_div_matrix_genes[rsv_div_matrix_genes$genome_region == g, ],
      n
    )
  })
)

bind_rows(ac_genome, ac_genes)

# %%
check_random_effects <- function(model, model_name) {
  
  vc <- VarCorr(model)
  
  # Extract from conditional model
  vc_cond <- vc$cond$location
  
  variance <- attr(vc_cond, "stddev")^2
  sd       <- attr(vc_cond, "stddev")
  
  data.frame(
    model     = model_name,
    variance  = round(variance, 6),
    sd        = round(sd, 6),
    near_zero = variance < 1e-4
  )
}



re_table <- bind_rows(
  lapply(names(all_models), function(n) {
    check_random_effects(all_models[[n]], n)
  })
)

print(re_table)

# %%
# Pivot to wide format for easy reading
diag_wide <- diag_results %>%
  select(model, test, problem) %>%
  tidyr::pivot_wider(names_from = test, values_from = problem) %>%
  left_join(
    ac_genome %>% bind_rows(ac_genes) %>%
      select(model, autocorrelation = problem),
    by = "model"
  ) %>%
  left_join(
    re_table %>% select(model, re_near_zero = near_zero),
    by = "model"
  )

print(diag_wide)
# Out:
# # A tibble: 12 × 7
#    model   uniformity dispersion outliers zero_infl autocorrelation re_near_zero
#    <chr>   <lgl>      <lgl>      <lgl>    <lgl>     <lgl>           <lgl>
#  1 entropy FALSE      FALSE      FALSE    FALSE     FALSE           FALSE
#  2 nuc_di… FALSE      FALSE      FALSE    FALSE     FALSE           FALSE
#  3 richne… FALSE      FALSE      FALSE    FALSE     FALSE           TRUE
#  4 low_fr… FALSE      FALSE      FALSE    FALSE     FALSE           TRUE
#  5 entrop… FALSE      FALSE      FALSE    FALSE     FALSE           FALSE
#  6 entrop… FALSE      FALSE      FALSE    FALSE     FALSE           TRUE
#  7 nuc_di… FALSE      FALSE      FALSE    FALSE     FALSE           FALSE
#  8 nuc_di… FALSE      FALSE      FALSE    FALSE     FALSE           TRUE
#  9 richne… FALSE      FALSE      FALSE    FALSE     FALSE           FALSE
# 10 richne… FALSE      FALSE      FALSE    FALSE     FALSE           TRUE
# 11 low_fr… FALSE      FALSE      FALSE    FALSE     FALSE           TRUE
# 12 low_fr… TRUE       TRUE       TRUE     FALSE     FALSE           FALSE

# %%
# Compare corresponding genome regions of different subtypes
stat_tests <- rsv_div_matrix %>%
  group_by(genome_region) %>%
  wilcox_test(entropy ~ subtype, paired = FALSE) %>%
  adjust_pvalue(method = "BH") %>%
  mutate(
    signif = case_when(
      p.adj < 0.001 ~ "***",
      p.adj < 0.01  ~ "**",
      p.adj < 0.05  ~ "*",
      TRUE          ~ "ns"  # not significant
    ))

stat_tests <- stat_tests %>%
  mutate(y.position = max(rsv_div_matrix$entropy) + 0.001)

stat_tests <- stat_tests %>%
  mutate(subtype = group1)  # ggplot will now find a column 'subtype'

stat_tests_regions <- stat_tests[c(1,2), ] %>%
  mutate(
    xmin = as.numeric(factor(genome_region)) - 0.2,
    xmax = as.numeric(factor(genome_region)) + 0.2
  )

stat_tests_genome <- stat_tests[c(3), ]

# %%
stat_tests
# Out:
#   genome_region .y.     group1 group2 n1 n2 statistic p        p.adj     signif
# 1 F             entropy RSV_A  RSV_B  51 69 2583      1.25e-05 1.875e-05 ***
# 2 G             entropy RSV_A  RSV_B  76 73 3125      1.83e-01 1.830e-01 ns
# 3 genome        entropy RSV_A  RSV_B  59 45 2245      1.78e-09 5.340e-09 ***
#   y.position subtype
# 1 0.03444998 RSV_A
# 2 0.03444998 RSV_A
# 3 0.03444998 RSV_A

# %% [markdown]
# The entropy values **between genome regions within RSV-A and RSV-B** samples were compared using the **paired Wilcoxon signed-rank test**. Significant differences were detected for both RSV-A (p-value = 3.553578e-07) and RSV-B (p-value = 0.0007611812), with the G gene exhibiting higher diversity than the F gene in each subtype.

# %%
print("median, min and max entropy values of genes and full genome of RSV-A and RSV-B")

rsv_div_matrix %>%
  group_by(subtype, genome_region) %>%
  summarize(
    median      = formatC(median(entropy), format = "e", digits = 2),
    min_entropy = formatC(min(entropy),    format = "e", digits = 2),
    max_entropy = formatC(max(entropy),    format = "e", digits = 2)
  )
# Out:
# [1] "median, min and max entropy values of genes and full genome of RSV-A and RSV-B"
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by subtype and genome_region.
# ℹ Output is grouped by subtype.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(subtype, genome_region))` for per-operation grouping
#   (`?dplyr::dplyr_by`) instead.
#   subtype genome_region median   min_entropy max_entropy
# 1 RSV_A   F             2.41e-03 1.55e-04    1.08e-02
# 2 RSV_A   G             5.58e-03 5.70e-04    2.15e-02
# 3 RSV_A   genome        5.73e-03 1.02e-03    1.09e-02
# 4 RSV_B   F             7.68e-04 5.50e-05    7.08e-03
# 5 RSV_B   G             4.51e-03 9.04e-05    3.34e-02
# 6 RSV_B   genome        2.74e-03 5.96e-04    6.53e-03

# %%
df_A <- rsv_div_matrix %>%
  filter(subtype == "RSV_A") %>%
  select(ID, genome_region, entropy) %>%
  filter(genome_region != "genome") %>%

  group_by(ID) %>%
  filter(n_distinct(genome_region) == 2) %>%
  ungroup()
head(df_A)


df_A_wide <- df_A %>%
  pivot_wider(
    id_cols = ID,
    names_from = genome_region,
    values_from = entropy
  )

# Store raw p-values
p_values <- c(
  wilcox.test(df_A_wide$F, df_A_wide$G, paired = TRUE)$p.value
)

# Adjust p-values
p_adj <- p.adjust(p_values, method = "BH")

# Show results
stat_between_genes_A <- data.frame(
  comparison = c("F vs G"),
  p_value = p_values,
  p_adjusted = p_adj
)
stat_between_genes_A
# Out:
#   ID               genome_region entropy
# 1 A2_17_2024_11_24 G             0.0019805914
# 2 A2_17_2024_11_24 F             0.0028228623
# 3 D1_10_2024_11_25 G             0.0029851261
# 4 D1_10_2024_11_25 F             0.0004864825
# 5 D1_10_2024_12_03 G             0.0019704036
# 6 D1_10_2024_12_03 F             0.0014079307
#   comparison p_value      p_adjusted
# 1 F vs G     4.208971e-10 4.208971e-10

# %%
df_B <- rsv_div_matrix %>%
  filter(subtype == "RSV_B") %>%
  select(ID, genome_region, entropy) %>%
  filter(genome_region != "genome") %>%
  group_by(ID) %>%
  filter(n_distinct(genome_region) == 2) %>%
  ungroup()

head(df_B)
df_B_wide <- df_B %>%
  pivot_wider(
    id_cols = ID,
    names_from = genome_region,
    values_from = entropy
  )

# Store raw p-values
p_values <- c(
  wilcox.test(df_B_wide$F, df_B_wide$G, paired = TRUE)$p.value
)

# Adjust p-values
p_adj <- p.adjust(p_values, method = "BH")

# Show results
stat_between_genes_B <- data.frame(
  comparison = c("F vs G"),
  p_value = p_values,
  p_adjusted = p_adj
)
stat_between_genes_B
# Out:
#   ID               genome_region entropy
# 1 A3_16_2024_11_23 G             0.0010035255
# 2 A3_16_2024_11_23 F             0.0004276065
# 3 B3_16_2024_11_25 G             0.0090014151
# 4 B3_16_2024_11_25 F             0.0006903321
# 5 F1_10_2024_12_08 G             0.0057905197
# 6 F1_10_2024_12_08 F             0.0007611812
#   comparison p_value      p_adjusted
# 1 F vs G     1.928644e-09 1.928644e-09

# %%
stat_between_genes <- bind_rows(
  stat_between_genes_A %>% mutate(subtype = "RSV-A"),
  stat_between_genes_B %>% mutate(subtype = "RSV-B")
) %>%
#stat_between_genes <-  rbind(stat_between_genes_A, stat_between_genes_B) %>%
  mutate(
    xmin = c(0.8, 1.2),
    xmax = c(1.8, 2.2),
    group1 = c("F", "F"),
    group2 = c("G", "G")#,
     # subtype= "RSV-A"
  ) %>% 
mutate(
    signif = case_when(
      p_adjusted < 0.001 ~ "***",
      p_adjusted < 0.01  ~ "**",
      p_adjusted < 0.05  ~ "*",
      TRUE               ~ "ns"  # not significant
    ))
stat_between_genes
# Out:
#   comparison p_value      p_adjusted   subtype xmin xmax group1 group2 signif
# 1 F vs G     4.208971e-10 4.208971e-10 RSV-A   0.8  1.8  F      G      ***
# 2 F vs G     1.928644e-09 1.928644e-09 RSV-B   1.2  2.2  F      G      ***

# %%
options(repr.plot.width = 10, repr.plot.height = 6)

# Add facet grouping
rsv_div_matrix <- rsv_div_matrix %>%

  mutate(
    facet_group = ifelse(genome_region == "genome", "Genome-wide", "Per-region")
  )

# --- Per-region plot ---
p_regions1 <- rsv_div_matrix %>%
  filter(facet_group == "Per-region") %>%
  ggplot(aes(x = genome_region, y = entropy, fill = subtype)) +
  geom_boxplot(
    position = position_dodge(width = 0.8),
    outlier.shape = NA,
    linewidth = 1,
    width = 0.7,
    colour = "black",
    alpha = 0.5
  ) +
  geom_jitter(
    position = position_jitterdodge(jitter.width = 0.15, dodge.width = 0.8),
    alpha = 0.6, size = 2.2, stroke = 0
  ) +
  scale_fill_manual(values = c("RSV_A" = "blue", "RSV_B" = "green3")) +
  labs(
    x = "Genome region",
    y = "Shannon entropy",
    title = "Per-region diversity",
    fill = "Subtype"
  ) +
  theme_bw(base_size = 18) +
  theme(
    legend.position = "top",
    strip.text = element_text(size = 23),
    strip.background = element_rect(fill = "grey90"),
    axis.title = element_text(size = 30),
    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 20, hjust = 0.5),
    legend.title = element_text(size = 25),
    legend.text = element_text(size = 22)
  ) 

# --- Genome-wide plot ---
p_genome1 <- rsv_div_matrix %>%
  filter(facet_group == "Genome-wide") %>%
  ggplot(aes(x = subtype, y = entropy, fill = subtype)) +
  geom_boxplot(width = 0.6, colour = "black", alpha = 0.5) +
  geom_jitter(width = 0.1, alpha = 0.6, size = 2.2) +
  scale_fill_manual(values = c("RSV_A" = "blue", "RSV_B" = "green3")) +
  labs(
    x = "Subtype",
    y = NULL,
    title = "Genome-wide diversity",
    fill = "Subtype"
  ) +
  theme_bw(base_size = 18) +
  theme(
    legend.position = "none",
    strip.text = element_text(size = 23),
    axis.title.x = element_text(size = 20),
    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 20, hjust = 0.5),
    legend.title = element_text(size = 20),
    legend.text = element_text(size = 22))

################################################################################################################
# P-values and significance: between-subtypes comparisons
################################################################################################################

# p_regions <- p_regions +
#   stat_pvalue_manual(
#     stat_tests_regions,
#     label = "signif",
#     xmin = "xmin",
#     xmax = "xmax",
#     y.position = 0.026,
#     tip.length = 0.02,
#     bracket.size = 1,
#     label.size = 6
#   ) +
#   stat_pvalue_manual(
#     stat_between_genes,
#     label = "signif",
#     xmin = "xmin",
#     xmax = "xmax",
#     y.position = c(0.028, 0.031),
#     tip.length = 0.02,
#     bracket.size = 1,
#     label.size = 6
#   )


# p_genome <- p_genome + 
#   stat_pvalue_manual(
#     stat_tests_genome,
#     label = "signif",
#     y.position = 0.013,       # adjust vertical position
#     tip.length = 0.05,
#     bracket.size = 1.2,
#     label.size = 6
#   )



# --- Combine with custom widths ---
p_final <- p_regions1 + p_genome1 + plot_layout(widths = c(2, 1))
p_final
# Out:
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 8)
ggplot(rsv_div_matrix, aes(x = entropy)) +
  geom_histogram(bins = 30, fill = "cadetblue", color = "black") +
facet_wrap(~ interaction(genome_region, subtype))+
  labs(title = "",
       x = "Entropy", y = "Count") +
  theme_minimal() +
  theme(
    legend.position = "right",
    strip.text = element_text(size = 20),
    axis.title.x = element_text(size = 20),
    axis.title.y = element_text(size = 20),

    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 28, hjust = 0.5))
# Out:
# plot without title

# %%
head(rsv_div_matrix)
# Out:
#   ID               date       location subtype genome_region entropy
# 1 F1_10_2024_11_09 2024-11-09 Zurich   RSV_A   G             0.0005695969
# 2 E1_10_2024_11_16 2024-11-16 Zurich   RSV_A   G             0.0023957615
# 3 A2_17_2024_11_24 2024-11-24 Chur     RSV_A   G             0.0019805914
# 4 A2_17_2024_11_24 2024-11-24 Chur     RSV_A   F             0.0028228623
# 5 A2_17_2024_11_24 2024-11-24 Chur     RSV_A   genome        0.0018235380
# 6 D1_10_2024_11_25 2024-11-25 Zurich   RSV_A   G             0.0029851261
#   nuc_diversity covered_part mean_pos_coverage richness low_freq_polymorphisms
# 1 0.0001973822  0.6946170    2021.683          25.33532 0.0000000
# 2 0.0013614424  0.5434783    3713.734          45.71429 0.0000000
# 3 0.0011097650  0.9648033    8454.416          25.75107 0.0000000
# 4 0.0019600457  0.6475362    3465.988          11.63832 0.8952551
# 5 0.0011297796  0.6011823    2667.041          16.16956 0.9832842
# 6 0.0018295970  0.6480331    4740.844          38.33866 1.5974441
#   facet_group
# 1 Per-region
# 2 Per-region
# 3 Per-region
# 4 Per-region
# 5 Genome-wide
# 6 Per-region

# %%
options(repr.plot.width = 15, repr.plot.height = 8)
# G and F diversity
ggplot(rsv_div_matrix, aes(x = nuc_diversity, color=subtype)) +
  geom_histogram(bins = 30, fill = "cadetblue", color = "black") +
facet_wrap(~ interaction(genome_region, subtype))+
  labs(title = "",
       x = "Nucleotide diversity", y = "Count") +
  theme_minimal() +
  theme(
    legend.position = "right",
    strip.text = element_text(size = 20),
    axis.title.x = element_text(size = 20),
    axis.title.y = element_text(size = 20),

    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 28, hjust = 0.5))
# Out:
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 8)
# G and F diversity
ggplot(rsv_div_matrix, aes(x = richness, color=subtype)) +
  geom_histogram(bins = 30, fill = "cadetblue", color = "black") +
facet_wrap(~ interaction(genome_region, subtype))+
  labs(title = "",
       x = "Richness", y = "Count") +
  theme_minimal() +
  theme(
    legend.position = "right",
    strip.text = element_text(size = 20),
    axis.title.x = element_text(size = 20),
    axis.title.y = element_text(size = 20),

    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 28, hjust = 0.5))
# Out:
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 8)
# G and F diversity
ggplot(rsv_div_matrix, aes(x = low_freq_polymorphisms, color=subtype)) +
  geom_histogram(bins = 30, fill = "cadetblue", color = "black") +
facet_wrap(~ interaction(genome_region, subtype))+
  labs(title = "",
       x = "Low frequency mutations", y = "Count") +
  theme_minimal() +
  theme(
    legend.position = "right",
    strip.text = element_text(size = 20),
    axis.title.x = element_text(size = 20),
    axis.title.y = element_text(size = 20),

    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 28, hjust = 0.5))
# Out:
# plot without title

# %% [markdown]
# # Nucleotide diversity

# %%
# Compare corresponding genome regions of different subtypes
stat_tests <- rsv_div_matrix %>%
  group_by(genome_region) %>%
  wilcox_test(nuc_diversity ~ subtype, paired = FALSE) %>%
  adjust_pvalue(method = "BH") %>%
mutate(
    signif = case_when(
      p.adj < 0.001 ~ "***",
      p.adj < 0.01  ~ "**",
      p.adj < 0.05  ~ "*",
      TRUE                ~ "ns"  # not significant
    ))


stat_tests <- stat_tests %>%
  mutate(y.position = max(rsv_div_matrix$nuc_diversity) + 0.001)

stat_tests <- stat_tests %>%
  rename(y.position = y.position) %>%  # make sure y.position is numeric
  mutate(subtype = group1)  # ggplot will now find a column 'subtype'

stat_tests_regions <- stat_tests[c(1,2), ] %>%
  mutate(
    xmin = as.numeric(factor(genome_region)) - 0.2,
    xmax = as.numeric(factor(genome_region)) + 0.2
  )

stat_tests_genome <- stat_tests[c(3), ]

# %%
df_A <- rsv_div_matrix %>%
  filter(subtype == "RSV_A") %>%
  select(ID, genome_region, nuc_diversity) %>%
  filter(genome_region != "genome") %>%

  group_by(ID) %>%
  filter(n_distinct(genome_region) == 2) %>%
  ungroup()
head(df_A)


df_A_wide <- df_A %>%
  pivot_wider(
    id_cols = ID,
    names_from = genome_region,
    values_from = nuc_diversity
  )

# Store raw p-values
p_values <- c(
  wilcox.test(df_A_wide$F, df_A_wide$G, paired = TRUE)$p.value
)

# Adjust p-values
p_adj <- p.adjust(p_values, method = "BH")

# Show results
stat_between_genes_A <- data.frame(
  comparison = c("F vs G"),
  p_value = p_values,
  p_adjusted = p_adj
)
stat_between_genes_A



df_B <- rsv_div_matrix %>%
  filter(subtype == "RSV_B") %>%
  select(ID, genome_region, nuc_diversity) %>%
  filter(genome_region != "genome") %>%
  group_by(ID) %>%
  filter(n_distinct(genome_region) == 2) %>%
  ungroup()

head(df_B)
df_B_wide <- df_B %>%
  pivot_wider(
    id_cols = ID,
    names_from = genome_region,
    values_from = nuc_diversity
  )

# Store raw p-values
p_values <- c(
  wilcox.test(df_B_wide$F, df_B_wide$G, paired = TRUE)$p.value
)

# Adjust p-values
p_adj <- p.adjust(p_values, method = "BH")

# Show results
stat_between_genes_B <- data.frame(
  comparison = c("F vs G"),
  p_value = p_values,
  p_adjusted = p_adj
)
stat_between_genes_B
# Out:
#   ID               genome_region nuc_diversity
# 1 A2_17_2024_11_24 G             0.0011097650
# 2 A2_17_2024_11_24 F             0.0019600457
# 3 D1_10_2024_11_25 G             0.0018295970
# 4 D1_10_2024_11_25 F             0.0002039714
# 5 D1_10_2024_12_03 G             0.0008241309
# 6 D1_10_2024_12_03 F             0.0010005065
#   comparison p_value      p_adjusted
# 1 F vs G     4.993524e-09 4.993524e-09
#   ID               genome_region nuc_diversity
# 1 A3_16_2024_11_23 G             0.0003626318
# 2 A3_16_2024_11_23 F             0.0002126296
# 3 B3_16_2024_11_25 G             0.0063284900
# 4 B3_16_2024_11_25 F             0.0004438918
# 5 F1_10_2024_12_08 G             0.0038805809
# 6 F1_10_2024_12_08 F             0.0004013542
#   comparison p_value      p_adjusted
# 1 F vs G     4.542948e-09 4.542948e-09

# %%
stat_between_genes <- bind_rows(
  stat_between_genes_A %>% mutate(subtype = "RSV-A"),
  stat_between_genes_B %>% mutate(subtype = "RSV-B")
) %>%
  mutate(
    xmin = c(0.8, 1.2),
    xmax = c(1.8, 2.2),
    group1 = c("F", "F"),
    group2 = c("G", "G")
  ) %>% 
mutate(
    signif = case_when(
      p_adjusted < 0.001 ~ "***",
      p_adjusted < 0.01  ~ "**",
      p_adjusted < 0.05  ~ "*",
      TRUE               ~ "ns"  # not significant
    ))
stat_between_genes
# Out:
#   comparison p_value      p_adjusted   subtype xmin xmax group1 group2 signif
# 1 F vs G     4.993524e-09 4.993524e-09 RSV-A   0.8  1.8  F      G      ***
# 2 F vs G     4.542948e-09 4.542948e-09 RSV-B   1.2  2.2  F      G      ***

# %%
options(repr.plot.width = 10, repr.plot.height = 6)

# Add facet grouping
rsv_div_matrix <- rsv_div_matrix %>%
  mutate(
    facet_group = ifelse(genome_region == "genome", "Genome-wide", "Per-region")
  )

# --- Per-region plot ---
p_regions2 <- rsv_div_matrix %>%
  filter(facet_group == "Per-region") %>%
  ggplot(aes(x = genome_region, y = nuc_diversity, fill = subtype)) +
  geom_boxplot(
    position = position_dodge(width = 0.8),
    outlier.shape = NA,
    linewidth = 1,
    width = 0.7,
    colour = "black",
    alpha = 0.5
  ) +
  geom_jitter(
    position = position_jitterdodge(jitter.width = 0.15, dodge.width = 0.8),
    alpha = 0.6, size = 2.2, stroke = 0
  ) +
  scale_fill_manual(values = c("RSV_A" = "blue", "RSV_B" = "green3")) +
  labs(
    x = "Genome region",
    y = "Nucleotide diversity",
    title = "Per-region diversity",
    fill = "Subtype"
  ) +
  theme_bw(base_size = 18) +
  theme(
    legend.position = "top",
    strip.text = element_text(size = 26),
    strip.background = element_rect(fill = "grey90", color = "black"),
    axis.title = element_text(size = 30),
    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 28, hjust = 0.5),
    legend.title = element_text(size = 25),
    legend.text = element_text(size = 22)
  ) 

# --- Genome-wide plot ---
p_genome2 <- rsv_div_matrix %>%
  filter(facet_group == "Genome-wide") %>%
  ggplot(aes(x = subtype, y = nuc_diversity, fill = subtype)) +
  geom_boxplot(width = 0.6, colour = "black", alpha = 0.5) +
  geom_jitter(width = 0.1, alpha = 0.6, size = 2.2) +
  scale_fill_manual(values = c("RSV_A" = "blue", "RSV_B" = "green3")) +
  labs(
    x = "Subtype",
    y = NULL,
    title = "Genome-wide diversity",
    fill = "Subtype"
  ) +
  theme_bw(base_size = 18) +
  theme(
    legend.position = "none",
    strip.text = element_text(size = 23),
    axis.title.x = element_text(size = 20,),
    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 20, hjust = 0.5))

################################################################################################################
# P-values and significance: between-subtypes comparisons
################################################################################################################

# p_regions <- p_regions +
#   stat_pvalue_manual(
#     stat_tests_regions,
#     label = "signif",
#     xmin = "xmin",
#     xmax = "xmax",
#     y.position = 0.018,
#     tip.length = 0.02,
#     bracket.size = 1,
#     label.size = 8
#   ) +
#   stat_pvalue_manual(
#     stat_between_genes,
#     label = "signif",
#     xmin = "xmin",
#     xmax = "xmax",
#     y.position = c(0.021, 0.024),
#     tip.length = 0.02,
#     bracket.size = 1,
#     label.size = 8
#   )


# p_genome <- p_genome + 
#   stat_pvalue_manual(
#     stat_tests_genome,
#     label = "signif",
#     y.position = 0.008,       # adjust vertical position
#     tip.length = 0.05,
#     bracket.size = 1.2,
#     label.size = 8
#   )



# --- Combine with custom widths ---
p_final <- p_regions2 + p_genome2 + plot_layout(widths = c(2, 1))
p_final
# Out:
# plot without title

# %% [markdown]
# # Richness

# %%
# Compare corresponding genome regions of different subtypes
stat_tests <- rsv_div_matrix %>%
  group_by(genome_region) %>%
  wilcox_test(richness ~ subtype, paired = FALSE) %>%
  adjust_pvalue(method = "BH") %>%
mutate(
    signif = case_when(
      p.adj < 0.001 ~ "***",
      p.adj < 0.01  ~ "**",
      p.adj < 0.05  ~ "*",
      TRUE                ~ "ns"  # not significant
    ))


stat_tests <- stat_tests %>%
  mutate(y.position = max(rsv_div_matrix$richness) + 0.001)

stat_tests <- stat_tests %>%
  rename(y.position = y.position) %>%  # make sure y.position is numeric
  mutate(subtype = group1)  # ggplot will now find a column 'subtype'

stat_tests_regions <- stat_tests[c(1,2), ] %>%
  mutate(
    xmin = as.numeric(factor(genome_region)) - 0.2,
    xmax = as.numeric(factor(genome_region)) + 0.2
  )

stat_tests_genome <- stat_tests[c(3), ]

# %%
df_A <- rsv_div_matrix %>%
  filter(subtype == "RSV_A") %>%
  select(ID, genome_region, richness) %>%
  filter(genome_region != "genome") %>%

  group_by(ID) %>%
  filter(n_distinct(genome_region) == 2) %>%
  ungroup()
head(df_A)


df_A_wide <- df_A %>%
  pivot_wider(
    id_cols = ID,
    names_from = genome_region,
    values_from = richness
  )

# Store raw p-values
p_values <- c(
  wilcox.test(df_A_wide$F, df_A_wide$G, paired = TRUE)$p.value
)

# Adjust p-values
p_adj <- p.adjust(p_values, method = "BH")

# Show results
stat_between_genes_A <- data.frame(
  comparison = c("F vs G"),
  p_value = p_values,
  p_adjusted = p_adj
)
stat_between_genes_A



df_B <- rsv_div_matrix %>%
  filter(subtype == "RSV_B") %>%
  select(ID, genome_region, richness) %>%
  filter(genome_region != "genome") %>%
  group_by(ID) %>%
  filter(n_distinct(genome_region) == 2) %>%
  ungroup()

head(df_B)
df_B_wide <- df_B %>%
  pivot_wider(
    id_cols = ID,
    names_from = genome_region,
    values_from = richness
  )

# Store raw p-values
p_values <- c(
  wilcox.test(df_B_wide$F, df_B_wide$G, paired = TRUE)$p.value
)

# Adjust p-values
p_adj <- p.adjust(p_values, method = "BH")

# Show results
stat_between_genes_B <- data.frame(
  comparison = c("F vs G"),
  p_value = p_values,
  p_adjusted = p_adj
)
stat_between_genes_B



stat_between_genes <- bind_rows(
  stat_between_genes_A %>% mutate(subtype = "RSV-A"),
  stat_between_genes_B %>% mutate(subtype = "RSV-B")
) %>%
#stat_between_genes <-  rbind(stat_between_genes_A, stat_between_genes_B) %>%
  mutate(
    xmin = c(0.8, 1.2),
    xmax = c(1.8, 2.2),
    group1 = c("F", "F"),
    group2 = c("G", "G")#,
     # subtype= "RSV-A"
  ) %>% 
mutate(
    signif = case_when(
      p_adjusted < 0.001 ~ "***",
      p_adjusted < 0.01  ~ "**",
      p_adjusted < 0.05  ~ "*",
      TRUE               ~ "ns"  # not significant
    ))
stat_between_genes
# Out:
#   ID               genome_region richness
# 1 A2_17_2024_11_24 G             25.75107
# 2 A2_17_2024_11_24 F             11.63832
# 3 D1_10_2024_11_25 G             38.33866
# 4 D1_10_2024_11_25 F             11.38647
# 5 D1_10_2024_12_03 G             39.33254
# 6 D1_10_2024_12_03 F             10.59002
#   comparison p_value      p_adjusted
# 1 F vs G     2.842171e-14 2.842171e-14
#   ID               genome_region richness
# 1 A3_16_2024_11_23 G             29.304029
# 2 A3_16_2024_11_23 F              8.560311
# 3 B3_16_2024_11_25 G             30.195382
# 4 B3_16_2024_11_25 F              8.750994
# 5 F1_10_2024_12_08 G             32.648126
# 6 F1_10_2024_12_08 F             10.366826
#   comparison p_value      p_adjusted
# 1 F vs G     5.971741e-10 5.971741e-10
#   comparison p_value      p_adjusted   subtype xmin xmax group1 group2 signif
# 1 F vs G     2.842171e-14 2.842171e-14 RSV-A   0.8  1.8  F      G      ***
# 2 F vs G     5.971741e-10 5.971741e-10 RSV-B   1.2  2.2  F      G      ***

# %%
options(repr.plot.width = 10, repr.plot.height =6)

# Add facet grouping
rsv_div_matrix <- rsv_div_matrix %>%
  mutate(
    facet_group = ifelse(genome_region == "genome", "Genome-wide", "Per-region")
  )

# --- Per-region plot ---
p_regions3 <- rsv_div_matrix %>%
  filter(facet_group == "Per-region") %>%
  ggplot(aes(x = genome_region, y = richness, fill = subtype)) +
  geom_boxplot(
    position = position_dodge(width = 0.8),
    outlier.shape = NA,
    linewidth = 1,
    width = 0.7,
    colour = "black",
    alpha = 0.5
  ) +
  geom_jitter(
    position = position_jitterdodge(jitter.width = 0.15, dodge.width = 0.8),
    alpha = 0.6, size = 2.2, stroke = 0
  ) +
  scale_fill_manual(values = c("RSV_A" = "blue", "RSV_B" = "green3")) +
  labs(
    x = "Genome region",
    y = "Richness",
    title = "Per-region diversity",
    fill = "Subtype"
  ) +
  theme_bw(base_size = 18) +
  theme(
    legend.position = "top",
    strip.text = element_text(size = 23),
    strip.background = element_rect(fill = "grey90", color = "black"),
    axis.title = element_text(size = 30),
    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 20, hjust = 0.5),
    legend.title = element_text(size = 25),
    legend.text = element_text(size = 22)
  ) 

# --- Genome-wide plot ---
p_genome3 <- rsv_div_matrix %>%
  filter(facet_group == "Genome-wide") %>%
  ggplot(aes(x = subtype, y = richness, fill = subtype)) +
  geom_boxplot(width = 0.6, colour = "black", alpha = 0.5) +
  geom_jitter(width = 0.1, alpha = 0.6, size = 2.2) +
  scale_fill_manual(values = c("RSV_A" = "blue", "RSV_B" = "green3")) +
  labs(
    x = "Subtype",
    y = NULL,
    title = "Genome-wide diversity",
    fill = "Subtype"
  ) +
  theme_bw(base_size = 18) +
  theme(
    legend.position = "none",
    strip.text = element_text(size = 23),
    axis.title.x = element_text(size = 20),
    axis.text = element_text(size = 20),
    axis.text.x = element_text(angle = 45, hjust = 1),
    plot.title = element_text(size = 20, hjust = 0.5),
    legend.title = element_text(size = 20),
    legend.text = element_text(size = 20))

################################################################################################################
# P-values and significance: between-subtypes comparisons
# ################################################################################################################

# p_regions <- p_regions +
#   stat_pvalue_manual(
#     stat_tests_regions,
#     label = "signif",
#     xmin = "xmin",
#     xmax = "xmax",
#     y.position = 62,
#     tip.length = 0.02,
#     bracket.size = 1,
#     label.size = 8
#   ) +
#   stat_pvalue_manual(
#     stat_between_genes,
#     label = "signif",
#     xmin = "xmin",
#     xmax = "xmax",
#     y.position = c(65, 69),
#     tip.length = 0.02,
#     bracket.size = 1,
#     label.size = 8
#   )


# p_genome <- p_genome + 
#   stat_pvalue_manual(
#     stat_tests_genome,
#     label = "signif",
#     y.position = 33,       # adjust vertical position
#     tip.length = 0.05,
#     bracket.size = 1.2,
#     label.size = 8
#   )



# --- Combine with custom widths ---
p_final <- p_regions3 + p_genome3 + plot_layout(widths = c(2, 1))
p_final
# Out:
# plot without title

# %% [markdown]
# # Low frequency polymorphisms

# %% [raw]
# # Compare corresponding genome regions of different subtypes
# stat_tests <- rsv_div_matrix %>%
#   group_by(genome_region) %>%
#   wilcox_test(low_freq_polymorphisms ~ subtype, paired = FALSE) %>%
#   adjust_pvalue(method = "BH") %>%
# mutate(
#     signif = case_when(
#       p.adj < 0.001 ~ "***",
#       p.adj < 0.01  ~ "**",
#       p.adj < 0.05  ~ "*",
#       TRUE                ~ "ns"  # not significant
#     ))
#
#
# stat_tests <- stat_tests %>%
#   mutate(y.position = max(rsv_div_matrix$low_freq_polymorphisms) + 0.001)
#
# stat_tests <- stat_tests %>%
#   rename(y.position = y.position) %>%  # make sure y.position is numeric
#   mutate(subtype = group1)  # ggplot will now find a column 'subtype'
#
# stat_tests_regions <- stat_tests[c(1,2), ] %>%
#   mutate(
#     xmin = as.numeric(factor(genome_region)) - 0.2,
#     xmax = as.numeric(factor(genome_region)) + 0.2
#   )
#
# stat_tests_genome <- stat_tests[c(3), ]

# %% [raw]
# df_A <- rsv_div_matrix %>%
#   filter(subtype == "RSV_A") %>%
#   select(ID, genome_region, low_freq_polymorphisms) %>%
#   filter(genome_region != "genome") %>%
#
#   group_by(ID) %>%
#   filter(n_distinct(genome_region) == 2) %>%
#   ungroup()
# head(df_A)
#
#
# df_A_wide <- df_A %>%
#   pivot_wider(
#     id_cols = ID,
#     names_from = genome_region,
#     values_from = low_freq_polymorphisms
#   )
#
# # Store raw p-values
# p_values <- c(
#   wilcox.test(df_A_wide$F, df_A_wide$G, paired = TRUE)$p.value
# )
#
# # Adjust p-values
# p_adj <- p.adjust(p_values, method = "BH")
#
# # Show results
# stat_between_genes_A <- data.frame(
#   comparison = c("F vs G"),
#   p_value = p_values,
#   p_adjusted = p_adj
# )
# stat_between_genes_A
#
#
#
# df_B <- rsv_div_matrix %>%
#   filter(subtype == "RSV_B") %>%
#   select(ID, genome_region, low_freq_polymorphisms) %>%
#   filter(genome_region != "genome") %>%
#   group_by(ID) %>%
#   filter(n_distinct(genome_region) == 2) %>%
#   ungroup()
#
# head(df_B)
# df_B_wide <- df_B %>%
#   pivot_wider(
#     id_cols = ID,
#     names_from = genome_region,
#     values_from = low_freq_polymorphisms
#   )
#
# # Store raw p-values
# p_values <- c(
#   wilcox.test(df_B_wide$F, df_B_wide$G, paired = TRUE)$p.value
# )
#
# # Adjust p-values
# p_adj <- p.adjust(p_values, method = "BH")
#
# # Show results
# stat_between_genes_B <- data.frame(
#   comparison = c("F vs G"),
#   p_value = p_values,
#   p_adjusted = p_adj
# )
# stat_between_genes_B
#
#
# stat_between_genes <- bind_rows(
#   stat_between_genes_A %>% mutate(subtype = "RSV-A"),
#   stat_between_genes_B %>% mutate(subtype = "RSV-B")
# ) %>%
# #stat_between_genes <-  rbind(stat_between_genes_A, stat_between_genes_B) %>%
#   mutate(
#     xmin = c(0.8, 1.2),
#     xmax = c(1.8, 2.2),
#     group1 = c("F", "F"),
#     group2 = c("G", "G")#,
#      # subtype= "RSV-A"
#   ) %>%
# mutate(
#     signif = case_when(
#       p_adjusted < 0.001 ~ "***",
#       p_adjusted < 0.01  ~ "**",
#       p_adjusted < 0.05  ~ "*",
#       TRUE               ~ "ns"  # not significant
#     ))
# stat_between_genes

# %% [raw]
# options(repr.plot.width = 14, repr.plot.height = 8)
#
# # Add facet grouping
# rsv_div_matrix <- rsv_div_matrix %>%
#   mutate(
#     facet_group = ifelse(genome_region == "genome", "Genome-wide", "Per-region")
#   )
#
# # --- Per-region plot ---
# p_regions <- rsv_div_matrix %>%
#   filter(facet_group == "Per-region") %>%
#   ggplot(aes(x = genome_region, y = low_freq_polymorphisms, fill = subtype)) +
#   geom_boxplot(
#     position = position_dodge(width = 0.8),
#     outlier.shape = NA,
#     linewidth = 1,
#     width = 0.7,
#     colour = "black",
#     alpha = 0.5
#   ) +
#   geom_jitter(
#     position = position_jitterdodge(jitter.width = 0.15, dodge.width = 0.8),
#     alpha = 0.6, size = 2.2, stroke = 0
#   ) +
#   scale_fill_manual(values = c("RSV_A" = "blue", "RSV_B" = "green3")) +
#   labs(
#     x = "Genome region",
#     y = "Low frequency mutations",
#     title = "Per-region diversity",
#     fill = "Subtype"
#   ) +
#   theme_bw(base_size = 18) +
#   theme(
#     legend.position = "none",
#     strip.text = element_text(size = 26),
#     strip.background = element_rect(fill = "grey90", color = "black"),
#     axis.title = element_text(size = 30),
#     axis.text = element_text(size = 20),
#     axis.text.x = element_text(angle = 45, hjust = 1),
#     plot.title = element_text(size = 28, hjust = 0.5)
#   )
#
# # --- Genome-wide plot ---
# p_genome <- rsv_div_matrix %>%
#   filter(facet_group == "Genome-wide") %>%
#   ggplot(aes(x = subtype, y = low_freq_polymorphisms, fill = subtype)) +
#   geom_boxplot(width = 0.6, colour = "black", alpha = 0.5) +
#   geom_jitter(width = 0.1, alpha = 0.6, size = 2.2) +
#   scale_fill_manual(values = c("RSV_A" = "blue", "RSV_B" = "green3")) +
#   labs(
#     x = "Subtype",
#     y = NULL,
#     title = "Genome-wide diversity",
#     fill = "Subtype"
#   ) +
#   theme_bw(base_size = 18) +
#   theme(
#     legend.position = "right",
#     strip.text = element_text(size = 26),
#     axis.title.x = element_text(size = 30),
#     axis.text = element_text(size = 20),
#     axis.text.x = element_text(angle = 45, hjust = 1),
#     plot.title = element_text(size = 28, hjust = 0.5),
#     legend.title = element_text(size = 30),
#     legend.text = element_text(size = 30))
#
# ################################################################################################################
# # P-values and significance: between-subtypes comparisons
# ################################################################################################################
#
# p_regions <- p_regions +
#   stat_pvalue_manual(
#     stat_tests_regions,
#     label = "signif",
#     xmin = "xmin",
#     xmax = "xmax",
#     y.position = 24,
#     tip.length = 0.02,
#     bracket.size = 1,
#     label.size = 8
#   ) +
#   stat_pvalue_manual(
#     stat_between_genes,
#     label = "signif",
#     xmin = "xmin",
#     xmax = "xmax",
#     y.position = c(26, 22),
#     tip.length = 0.02,
#     bracket.size = 1,
#     label.size = 8
#   )
#
#
# p_genome <- p_genome +
#   stat_pvalue_manual(
#     stat_tests_genome,
#     label = "signif",
#     y.position = 7,       # adjust vertical position
#     tip.length = 0.05,
#     bracket.size = 1.2,
#     label.size = 8
#   )
#
#
#
# # --- Combine with custom widths ---
# p_final <- p_regions + p_genome + plot_layout(widths = c(2.5, 1))
# p_final

# %%
options(repr.plot.width = 20, repr.plot.height =9)

p_regions2 + p_genome2 +p_regions3 + p_genome3 +  p_regions1 + p_genome1  +  plot_layout(widths = c(2,1,2,1,2,1))
# Out:
# plot without title
